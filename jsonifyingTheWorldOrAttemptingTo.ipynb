# %%
import csv
import json

# %%
csv_file_path = '../CSVs/lists.csv'
json_file_path = './lists.json'

# %%
data = []

with open(csv_file_path, 'r') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        data.append(row)

with open(json_file_path, 'w') as json_file:
    json.dump(data, json_file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/lx/kd28k3fd73zdt8856kql3c7m0000gn/T/ipykernel_11394/517541603.py in <module>
#       1 data = []
#       2
# ----> 3 with open(csv_file_path, 'r') as csv_file:
#       4     reader = csv.DictReader(csv_file)
#       5     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../CSVs/lists.csv'
