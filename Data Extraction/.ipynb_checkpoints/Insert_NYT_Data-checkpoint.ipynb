# %%
# Dependencies
from datetime import date, timedelta, datetime
import requests
import pandas as pd
from time import sleep
import pprint as pp
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# Import local settings
from local_postgres import postgresql as pg
from api_keys import nyt_apikey_1, nyt_apikey_2

# %%
# Create URL string for API calls
url = f"https://api.nytimes.com/svc/books/v3/lists/full-overview.json?published_date=2022-12-15&api-key={nyt_apikey_1}"

# Make API request
response = requests.get(url).json()

# View response
pp.pprint(response)

# Empty list which will later be used to create Pandas Dataframe
book_data = []

# Published date
pub_date = datetime.strptime(response['results']['published_date'], '%Y-%m-%d').date()

# Loop through each list in the response
for blist in response['results']['lists']:
    
    list_name = blist['list_name']
    
#     Loop through each book in the list
    for book in blist['books']:
        
        # Append book-related information
        book_data.append({
            'NYT List': list_name,
            'NYT List Published Date': pub_date,            
            'Title': book['title'],
            'Author': book['author'],
            'Imprint': book['publisher'],
            'Rank': book['rank'],
            'Weeks on NYT List': book['weeks_on_list'],
            'Image': book['book_image'],
            'Description': book['description']
        })
# Out:
# {'copyright': 'Copyright (c) 2023 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 230,
#  'results': {'bestsellers_date': '2022-12-31',
#              'lists': [{'books': [{'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/1668001225?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Colleen Hoover',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781668001226.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 322,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/3aa85e47-4df9-53ef-9957-a77753d3502c',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/1668001225?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781668001226?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781668001226'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FIT%252BSTARTS%252BWITH%252BUS%252FColleen%252BHoover%252F9781668001226&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DIT%252BSTARTS%252BWITH%252BUS%252BColleen%252BHoover'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781668001226&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DIT%2BSTARTS%2BWITH%2BUS'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781668001226%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DIT%2BSTARTS%2BWITH%2BUS%2BColleen%2BHoover%26aff%3DNYT'}],
#                                    'contributor': 'by Colleen Hoover',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'In the sequel to “It Ends '
#                                                   'With Us,” Lily deals with '
#                                                   'her jealous ex-husband as '
#                                                   'she reconnects with her '
#                                                   'first boyfriend.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1668001225',
#                                    'primary_isbn13': '9781668001226',
#                                    'publisher': 'Atria',
#                                    'rank': 1,
#                                    'rank_last_week': 1,
#                                    'sunday_review_link': '',
#                                    'title': 'IT STARTS WITH US',
#                                    'updated_date': '2023-01-04 23:14:49',
#                                    'weeks_on_list': 11},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/038554734X?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Bonnie Garmus',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780385547345.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 328,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/717e0ead-9782-567d-af27-d9a6cfb1856f',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/038554734X?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9780385547345?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780385547345'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FLESSONS%252BIN%252BCHEMISTRY%252FBonnie%252BGarmus%252F9780385547345&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DLESSONS%252BIN%252BCHEMISTRY%252BBonnie%252BGarmus'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9780385547345&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DLESSONS%2BIN%2BCHEMISTRY'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9780385547345%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DLESSONS%2BIN%2BCHEMISTRY%2BBonnie%2BGarmus%26aff%3DNYT'}],
#                                    'contributor': 'by Bonnie Garmus',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'A scientist and single '
#                                                   'mother living in California '
#                                                   'in the 1960s becomes a star '
#                                                   'on a TV cooking show.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '038554734X',
#                                    'primary_isbn13': '9780385547345',
#                                    'publisher': 'Doubleday',
#                                    'rank': 2,
#                                    'rank_last_week': 3,
#                                    'sunday_review_link': '',
#                                    'title': 'LESSONS IN CHEMISTRY',
#                                    'updated_date': '2023-01-04 23:14:49',
#                                    'weeks_on_list': 8},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'http://www.amazon.com/Ends-Us-Novel-Colleen-Hoover-ebook/dp/B0176M3U10?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Colleen Hoover',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781501110375.jpg',
#                                    'book_image_height': 495,
#                                    'book_image_width': 319,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/e2a3545e-e9cb-5828-9d97-50a798a0e4f6',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'http://www.amazon.com/Ends-Us-Novel-Colleen-Hoover-ebook/dp/B0176M3U10?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781501110368?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781501110368'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FIT%252BENDS%252BWITH%252BUS%252FColleen%252BHoover%252F9781501110368&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DIT%252BENDS%252BWITH%252BUS%252BColleen%252BHoover'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781501110368&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DIT%2BENDS%2BWITH%2BUS'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781501110368%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DIT%2BENDS%2BWITH%2BUS%2BColleen%2BHoover%26aff%3DNYT'}],
#                                    'contributor': 'by Colleen Hoover',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'A battered wife raised in a '
#                                                   'violent home attempts to '
#                                                   'halt the cycle of abuse.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1501110365',
#                                    'primary_isbn13': '9781501110368',
#                                    'publisher': 'Atria',
#                                    'rank': 3,
#                                    'rank_last_week': 2,
#                                    'sunday_review_link': '',
#                                    'title': 'IT ENDS WITH US',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 81},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/1791392792?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Colleen Hoover',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781791392796.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 324,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/013c7729-a1de-5e5c-921a-da43243f9a4a',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/1791392792?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781538724736?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781538724736'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FVERITY%252FColleen%252BHoover%252F9781538724736&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DVERITY%252BColleen%252BHoover'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781538724736&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DVERITY'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781538724736%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DVERITY%2BColleen%2BHoover%26aff%3DNYT'}],
#                                    'contributor': 'by Colleen Hoover',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'Lowen Ashleigh is hired by '
#                                                   'the husband of an injured '
#                                                   'writer to complete her '
#                                                   'popular series and uncovers '
#                                                   'a horrifying truth.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1538724731',
#                                    'primary_isbn13': '9781538724736',
#                                    'publisher': 'Grand Central',
#                                    'rank': 4,
#                                    'rank_last_week': 4,
#                                    'sunday_review_link': '',
#                                    'title': 'VERITY',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 56},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/1501161938?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Taylor Jenkins Reid',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781501161933.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 315,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/d9511fac-ee44-5a87-9af7-2cd6a6f8f984',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/1501161938?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781501161933?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781501161933'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FTHE%252BSEVEN%252BHUSBANDS%252BOF%252BEVELYN%252BHUGO%252FTaylor%252BJenkins%252BReid%252F9781501161933&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DTHE%252BSEVEN%252BHUSBANDS%252BOF%252BEVELYN%252BHUGO%252BTaylor%252BJenkins%252BReid'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781501161933&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DTHE%2BSEVEN%2BHUSBANDS%2BOF%2BEVELYN%2BHUGO'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781501161933%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DTHE%2BSEVEN%2BHUSBANDS%2BOF%2BEVELYN%2BHUGO%2BTaylor%2BJenkins%2BReid%26aff%3DNYT'}],
#                                    'contributor': 'by Taylor Jenkins Reid',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'A movie icon recounts '
#                                                   'stories of her loves and '
#                                                   'career to a struggling '
#                                                   'magazine writer.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1501161938',
#                                    'primary_isbn13': '9781501161933',
#                                    'publisher': 'Washington Square/Atria',
#                                    'rank': 5,
#                                    'rank_last_week': 9,
#                                    'sunday_review_link': '',
#                                    'title': 'THE SEVEN HUSBANDS OF EVELYN HUGO',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 78},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/1984818384?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Jodi Picoult and Jennifer Finney '
#                                              'Boylan',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781984818386.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 328,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/85b00f04-42ad-5dbc-9cd0-d057ff1eff68',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/1984818384?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781984818393?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781984818393'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FMAD%252BHONEY%252FJodi%252BPicoult%252Band%252BJennifer%252BFinney%252BBoylan%252F9781984818393&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DMAD%252BHONEY%252BJodi%252BPicoult%252Band%252BJennifer%252BFinney%252BBoylan'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781984818393&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DMAD%2BHONEY'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781984818393%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DMAD%2BHONEY%2BJodi%2BPicoult%2Band%2BJennifer%2BFinney%2BBoylan%26aff%3DNYT'}],
#                                    'contributor': 'by Jodi Picoult and '
#                                                   'Jennifer Finney Boylan',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'After returning to her '
#                                                   'hometown, Olivia McAfee’s '
#                                                   'son gets accused of killing '
#                                                   'his crush.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1984818392',
#                                    'primary_isbn13': '9781984818393',
#                                    'publisher': 'Ballantine',
#                                    'rank': 6,
#                                    'rank_last_week': 15,
#                                    'sunday_review_link': '',
#                                    'title': 'MAD HONEY',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 11},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'http://www.amazon.com/Ugly-Love-Novel-Colleen-Hoover-ebook/dp/B00HB62MC0?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Colleen Hoover',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781476753195.jpg',
#                                    'book_image_height': 198,
#                                    'book_image_width': 128,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/08464a1b-cfd4-5d1b-8898-e206fb95deeb',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'http://www.amazon.com/Ugly-Love-Novel-Colleen-Hoover-ebook/dp/B00HB62MC0?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781476753188?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781476753188'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FUGLY%252BLOVE%252FColleen%252BHoover%252F9781476753188&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DUGLY%252BLOVE%252BColleen%252BHoover'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781476753188&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DUGLY%2BLOVE'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781476753188%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DUGLY%2BLOVE%2BColleen%2BHoover%26aff%3DNYT'}],
#                                    'contributor': 'by Colleen Hoover',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'Tate Collins and Miles '
#                                                   'Archer,\xa0an airline '
#                                                   'pilot, think they can '
#                                                   'handle a no strings '
#                                                   'attached arrangement. But '
#                                                   "they can't.",
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1476753180',
#                                    'primary_isbn13': '9781476753188',
#                                    'publisher': 'Atria',
#                                    'rank': 7,
#                                    'rank_last_week': 8,
#                                    'sunday_review_link': '',
#                                    'title': 'UGLY LOVE',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 51},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/0593321200?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Gabrielle Zevin',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780593321201.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 329,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/bc07e3e3-e917-50bb-9439-70118335f40c',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/0593321200?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9780593321201?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780593321201'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FTOMORROW%25252C%252BAND%252BTOMORROW%25252C%252BAND%252BTOMORROW%252FGabrielle%252BZevin%252F9780593321201&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DTOMORROW%25252C%252BAND%252BTOMORROW%25252C%252BAND%252BTOMORROW%252BGabrielle%252BZevin'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9780593321201&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DTOMORROW%252C%2BAND%2BTOMORROW%252C%2BAND%2BTOMORROW'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9780593321201%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DTOMORROW%252C%2BAND%2BTOMORROW%252C%2BAND%2BTOMORROW%2BGabrielle%2BZevin%26aff%3DNYT'}],
#                                    'contributor': 'by Gabrielle Zevin',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'Two friends find their '
#                                                   'partnership challenged in '
#                                                   'the world of video game '
#                                                   'design.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '0593321200',
#                                    'primary_isbn13': '9780593321201',
#                                    'publisher': 'Knopf',
#                                    'rank': 8,
#                                    'rank_last_week': 0,
#                                    'sunday_review_link': '',
#                                    'title': 'TOMORROW, AND TOMORROW, AND '
#                                             'TOMORROW',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 3},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/0385548923?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'John Grisham',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780385548922.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 329,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/b59f42c0-d9d0-5535-bf4b-21e5d04d3a46',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/0385548923?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9780385548922?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780385548922'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FTHE%252BBOYS%252BFROM%252BBILOXI%252FJohn%252BGrisham%252F9780385548922&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DTHE%252BBOYS%252BFROM%252BBILOXI%252BJohn%252BGrisham'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9780385548922&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DTHE%2BBOYS%2BFROM%2BBILOXI'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9780385548922%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DTHE%2BBOYS%2BFROM%2BBILOXI%2BJohn%2BGrisham%26aff%3DNYT'}],
#                                    'contributor': 'by John Grisham',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'Two childhood friends '
#                                                   'follow in their fathers’ '
#                                                   'footsteps, which puts them '
#                                                   'on opposite sides of the '
#                                                   'law.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '0385548923',
#                                    'primary_isbn13': '9780385548922',
#                                    'publisher': 'Doubleday',
#                                    'rank': 9,
#                                    'rank_last_week': 5,
#                                    'sunday_review_link': '',
#                                    'title': 'THE BOYS FROM BILOXI',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 11},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/0316485659?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Michael Connelly',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780316485654.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 323,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/614ddcff-2c72-5736-9e90-03bdaacf91f8',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/0316485659?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9780316421461?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316421461'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FDESERT%252BSTAR%252FMichael%252BConnelly%252F9780316421461&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DDESERT%252BSTAR%252BMichael%252BConnelly'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9780316421461&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DDESERT%2BSTAR'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9780316421461%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DDESERT%2BSTAR%2BMichael%2BConnelly%26aff%3DNYT'}],
#                                    'contributor': 'by Michael Connelly',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'Ballard and Bosch bury old '
#                                                   'resentments as they go '
#                                                   'after two killers.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '0316421464',
#                                    'primary_isbn13': '9780316421461',
#                                    'publisher': 'Little, Brown',
#                                    'rank': 10,
#                                    'rank_last_week': 0,
#                                    'sunday_review_link': '',
#                                    'title': 'DESERT STAR',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 6},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/059344955X?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Nicholas Sparks',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780593449554.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 331,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/822b15da-e34a-53d7-889c-58e54f555fbb',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/059344955X?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9780593449561?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780593449561'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FDREAMLAND%252FNicholas%252BSparks%252F9780593449561&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DDREAMLAND%252BNicholas%252BSparks'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9780593449561&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DDREAMLAND'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9780593449561%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DDREAMLAND%2BNicholas%2BSparks%26aff%3DNYT'}],
#                                    'contributor': 'by Nicholas Sparks',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'Musicians from different '
#                                                   'backgrounds are attracted '
#                                                   'to each other and a mother '
#                                                   'flees with her son from an '
#                                                   'abusive husband.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '0593449568',
#                                    'primary_isbn13': '9780593449561',
#                                    'publisher': 'Random House',
#                                    'rank': 11,
#                                    'rank_last_week': 11,
#                                    'sunday_review_link': '',
#                                    'title': 'DREAMLAND',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 8},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/0063251922?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Barbara Kingsolver',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780063251922.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 329,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/8e483e84-3941-58c1-834a-6b37ce4ff5ad',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/0063251922?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9780063251991?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780063251991'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FDEMON%252BCOPPERHEAD%252FBarbara%252BKingsolver%252F9780063251991&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DDEMON%252BCOPPERHEAD%252BBarbara%252BKingsolver'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9780063251991&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DDEMON%2BCOPPERHEAD'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9780063251991%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DDEMON%2BCOPPERHEAD%2BBarbara%2BKingsolver%26aff%3DNYT'}],
#                                    'contributor': 'by Barbara Kingsolver',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:10:26',
#                                    'description': 'A reimagining of Charles '
#                                                   'Dickens’s “David '
#                                                   'Copperfield” set in the '
#                                                   'mountains of southern '
#                                                   'Appalachia.',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '006325199X',
#                                    'primary_isbn13': '9780063251991',
#                                    'publisher': 'Harper',
#                                    'rank': 12,
#                                    'rank_last_week': 10,
#                                    'sunday_review_link': '',
#                                    'title': 'DEMON COPPERHEAD',
#                                    'updated_date': '2023-01-04 23:14:50',
#                                    'weeks_on_list': 8},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/Silent-Patient-Alex-Michaelides/dp/1250301696?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Alex Michaelides',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781250301697.jpg',
#                                    'book_image_height': 495,
#                                    'book_image_width': 326,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/b29e079d-2ac4-54bf-b6da-ca9daa59f616',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/Silent-Patient-Alex-Michaelides/dp/1250301696?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781250301703?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250301703'},
#                                                  {'name': 'Books-A-Million',
# ...
#                                    'primary_isbn10': '1534467637',
#                                    'primary_isbn13': '9781534467637',
#                                    'publisher': 'Simon & Schuster',
#                                    'rank': 6,
#                                    'rank_last_week': 0,
#                                    'sunday_review_link': '',
#                                    'title': 'BETTER THAN THE MOVIES',
#                                    'updated_date': '2023-01-04 23:54:17',
#                                    'weeks_on_list': 0},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'http://www.amazon.com/The-Way-I-Used-Be/dp/1481449354?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Amber Smith',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781481449359.jpg',
#                                    'book_image_height': 495,
#                                    'book_image_width': 324,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/bc9d9c11-51e8-5885-9239-fa84b126632d',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'http://www.amazon.com/The-Way-I-Used-Be/dp/1481449354?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781481449366?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781481449366'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FTHE%252BWAY%252BI%252BUSED%252BTO%252BBE%252FAmber%252BSmith%252F9781481449366&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DTHE%252BWAY%252BI%252BUSED%252BTO%252BBE%252BAmber%252BSmith'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781481449366&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DTHE%2BWAY%2BI%2BUSED%2BTO%2BBE'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781481449366%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DTHE%2BWAY%2BI%2BUSED%2BTO%2BBE%2BAmber%2BSmith%26aff%3DNYT'}],
#                                    'contributor': 'by Amber Smith',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:54:17',
#                                    'description': '',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1481449362',
#                                    'primary_isbn13': '9781481449366',
#                                    'publisher': 'Margaret K. McElderry',
#                                    'rank': 7,
#                                    'rank_last_week': 0,
#                                    'sunday_review_link': '',
#                                    'title': 'THE WAY I USED TO BE',
#                                    'updated_date': '2023-01-04 23:54:17',
#                                    'weeks_on_list': 0},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/1974732525?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Aya Yajima.',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781974732524.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 333,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/50f19bc9-d8d9-5ed4-a3ec-acd395afe6fb',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/1974732525?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781974732524?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781974732524'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FDEMON%252BSLAYER%25253A%252BKIMETSU%252BNO%252BYAIBA--THE%252BFLOWER%252BOF%252BHAPPINESS%252FAya%252BYajima.%252F9781974732524&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DDEMON%252BSLAYER%25253A%252BKIMETSU%252BNO%252BYAIBA--THE%252BFLOWER%252BOF%252BHAPPINESS%252BAya%252BYajima.'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781974732524&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DDEMON%2BSLAYER%253A%2BKIMETSU%2BNO%2BYAIBA--THE%2BFLOWER%2BOF%2BHAPPINESS'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781974732524%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DDEMON%2BSLAYER%253A%2BKIMETSU%2BNO%2BYAIBA--THE%2BFLOWER%2BOF%2BHAPPINESS%2BAya%2BYajima.%26aff%3DNYT'}],
#                                    'contributor': 'by Aya Yajima. Illustrated '
#                                                   'by Koyoharu Gotouge',
#                                    'contributor_note': 'Illustrated by '
#                                                        'Koyoharu Gotouge',
#                                    'created_date': '2023-01-04 23:54:17',
#                                    'description': '',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1974732525',
#                                    'primary_isbn13': '9781974732524',
#                                    'publisher': 'Viz Media',
#                                    'rank': 8,
#                                    'rank_last_week': 0,
#                                    'sunday_review_link': '',
#                                    'title': 'DEMON SLAYER: KIMETSU NO '
#                                             'YAIBA--THE FLOWER OF HAPPINESS',
#                                    'updated_date': '2023-01-04 23:54:17',
#                                    'weeks_on_list': 0},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'https://www.amazon.com/dp/1534441603?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Tracy Deonn',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781534441606.jpg',
#                                    'book_image_height': 500,
#                                    'book_image_width': 328,
#                                    'book_review_link': '',
#                                    'book_uri': 'nyt://book/18c7f534-63c9-52f7-90e4-d74d16b6fdaf',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'https://www.amazon.com/dp/1534441603?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9781534441613?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781534441613'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FLEGENDBORN%252FTracy%252BDeonn%252F9781534441613&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DLEGENDBORN%252BTracy%252BDeonn'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9781534441613&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DLEGENDBORN'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9781534441613%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DLEGENDBORN%2BTracy%2BDeonn%26aff%3DNYT'}],
#                                    'contributor': 'by Tracy Deonn',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:54:17',
#                                    'description': '',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '1534441611',
#                                    'primary_isbn13': '9781534441613',
#                                    'publisher': 'Margaret K. McElderry',
#                                    'rank': 9,
#                                    'rank_last_week': 0,
#                                    'sunday_review_link': '',
#                                    'title': 'LEGENDBORN',
#                                    'updated_date': '2023-01-04 23:54:17',
#                                    'weeks_on_list': 0},
#                                   {'age_group': '',
#                                    'amazon_product_url': 'http://www.amazon.com/The-Book-Thief-Markus-Zusak/dp/0375842209?tag=NYTBSREV-20',
#                                    'article_chapter_link': '',
#                                    'author': 'Markus Zusak',
#                                    'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780375842207.jpg',
#                                    'book_image_height': 495,
#                                    'book_image_width': 321,
#                                    'book_review_link': 'https://www.nytimes.com/2006/03/27/books/27masl.html',
#                                    'book_uri': 'nyt://book/535c6937-87ea-5803-a820-cc3cb3114056',
#                                    'buy_links': [{'name': 'Amazon',
#                                                   'url': 'http://www.amazon.com/The-Book-Thief-Markus-Zusak/dp/0375842209?tag=NYTBSREV-20'},
#                                                  {'name': 'Apple Books',
#                                                   'url': 'https://goto.applebooks.apple/9780375842207?at=10lIEQ'},
#                                                  {'name': 'Barnes and Noble',
#                                                   'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780375842207'},
#                                                  {'name': 'Books-A-Million',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fp%252FTHE%252BBOOK%252BTHIEF%252FMarkus%252BZusak%252F9780375842207&url2=https%3A%2F%2Fwww.anrdoezrs.net%2Fclick-7990613-35140%3Furl%3Dhttps%253A%252F%252Fwww.booksamillion.com%252Fsearch%253Fquery%253DTHE%252BBOOK%252BTHIEF%252BMarkus%252BZusak'},
#                                                  {'name': 'Bookshop',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fbookshop.org%2Fa%2F3546%2F9780375842207&url2=https%3A%2F%2Fbookshop.org%2Fbooks%3Faffiliate%3D3546%26keywords%3DTHE%2BBOOK%2BTHIEF'},
#                                                  {'name': 'IndieBound',
#                                                   'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/redirect?url1=https%3A%2F%2Fwww.indiebound.org%2Fbook%2F9780375842207%3Faff%3DNYT&url2=https%3A%2F%2Fwww.indiebound.org%2Fsearch%2Fbook%3Fkeys%3DTHE%2BBOOK%2BTHIEF%2BMarkus%2BZusak%26aff%3DNYT'}],
#                                    'contributor': 'by Markus Zusak',
#                                    'contributor_note': '',
#                                    'created_date': '2023-01-04 23:54:17',
#                                    'description': '',
#                                    'first_chapter_link': '',
#                                    'price': '0.00',
#                                    'primary_isbn10': '0375842209',
#                                    'primary_isbn13': '9780375842207',
#                                    'publisher': 'Knopf',
#                                    'rank': 10,
#                                    'rank_last_week': 0,
#                                    'sunday_review_link': 'https://www.nytimes.com/2006/05/14/books/review/14greenj.html',
#                                    'title': 'THE BOOK THIEF',
#                                    'updated_date': '2023-01-04 23:54:17',
#                                    'weeks_on_list': 0}],
#                         'display_name': 'Young Adult Paperback',
#                         'list_id': 10016,
#                         'list_image': None,
#                         'list_image_height': None,
#                         'list_image_width': None,
#                         'list_name': 'Young Adult Paperback Monthly',
#                         'list_name_encoded': 'young-adult-paperback-monthly',
#                         'updated': 'MONTHLY'}],
#              'next_published_date': '2023-01-22',
#              'previous_published_date': '2023-01-08',
#              'published_date': '2023-01-15',
#              'published_date_description': ''},
#  'status': 'OK'}

# %%
# Store book information in pandas dataframe
book_df = pd.DataFrame(book_data)
book_df
# Out:
#                               NYT List NYT List Published Date  \
# 0    Combined Print and E-Book Fiction              2023-01-15
# 1    Combined Print and E-Book Fiction              2023-01-15
# 2    Combined Print and E-Book Fiction              2023-01-15
# 3    Combined Print and E-Book Fiction              2023-01-15
# 4    Combined Print and E-Book Fiction              2023-01-15
# ..                                 ...                     ...
# 225      Young Adult Paperback Monthly              2023-01-15
# 226      Young Adult Paperback Monthly              2023-01-15
# 227      Young Adult Paperback Monthly              2023-01-15
# 228      Young Adult Paperback Monthly              2023-01-15
# 229      Young Adult Paperback Monthly              2023-01-15
#
#                                                  Title               Author  \
# 0                                    IT STARTS WITH US       Colleen Hoover
# 1                                 LESSONS IN CHEMISTRY        Bonnie Garmus
# 2                                      IT ENDS WITH US       Colleen Hoover
# 3                                               VERITY       Colleen Hoover
# 4                    THE SEVEN HUSBANDS OF EVELYN HUGO  Taylor Jenkins Reid
# ..                                                 ...                  ...
# 225                             BETTER THAN THE MOVIES         Lynn Painter
# 226                               THE WAY I USED TO BE          Amber Smith
# 227  DEMON SLAYER: KIMETSU NO YAIBA--THE FLOWER OF ...          Aya Yajima.
# 228                                         LEGENDBORN          Tracy Deonn
# 229                                     THE BOOK THIEF         Markus Zusak
#
#                      Imprint  Rank  Weeks on NYT List  \
# 0                      Atria     1                 11
# 1                  Doubleday     2                  8
# 2                      Atria     3                 81
# 3              Grand Central     4                 56
# 4    Washington Square/Atria     5                 78
# ..                       ...   ...                ...
# 225         Simon & Schuster     6                  0
# 226    Margaret K. McElderry     7                  0
# 227                Viz Media     8                  0
# 228    Margaret K. McElderry     9                  0
# 229                    Knopf    10                  0
#
#                                                  Image  \
# 0    https://storage.googleapis.com/du-prd/books/im...
# 1    https://storage.googleapis.com/du-prd/books/im...
# 2    https://storage.googleapis.com/du-prd/books/im...
# 3    https://storage.googleapis.com/du-prd/books/im...
# 4    https://storage.googleapis.com/du-prd/books/im...
# ..                                                 ...
# 225  https://storage.googleapis.com/du-prd/books/im...
# 226  https://storage.googleapis.com/du-prd/books/im...
# 227  https://storage.googleapis.com/du-prd/books/im...
# 228  https://storage.googleapis.com/du-prd/books/im...
# 229  https://storage.googleapis.com/du-prd/books/im...
#
#                                            Description
# 0    In the sequel to “It Ends With Us,” Lily deals...
# 1    A scientist and single mother living in Califo...
# 2    A battered wife raised in a violent home attem...
# 3    Lowen Ashleigh is hired by the husband of an i...
# 4    A movie icon recounts stories of her loves and...
# ..                                                 ...
# 225
# 226
# 227
# 228
# 229
#
# [230 rows x 9 columns]

# %%
# Create SQLAlchemy engine
pg_path = f"postgresql+psycopg2://{pg['user']}:{pg['password']}@{pg['host']}:{pg['port']}/{pg['db']}"
engine = create_engine(pg_path)

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Create session
session = Session(engine)

# %%
Base.classes.keys()
# Out:
# ['imprints', 'ownership', 'publishers', 'authors', 'books', 'lists', 'results']

# %%
Authors = Base.classes.authors
Books = Base.classes.books
Imprints = Base.classes.imprints
Lists = Base.classes.lists
Results = Base.classes.results
Publishers = Base.classes.publishers
Ownership = Base.classes.ownership

# %%
lists_from_df = book_df['NYT List'].unique()
lists_from_pg = list(blist[0] for blist in session.query(Lists.list_name).all())
lists_to_add = list(blist for blist in lists_from_df if blist not in lists_from_pg)

if len(lists_to_add) > 0:
    for blist in lists_to_add:
        session.add(Lists(list_name=blist))
    session.commit()

# %%
imprints_from_df = book_df['Imprint'].unique()
imprints_from_pg = list(imprint[0] for imprint in session.query(Imprints.imprint_name).all())
imprints_to_add = list(imprint for imprint in imprints_from_df if imprint not in imprints_from_pg)

if len(imprints_to_add) > 0:
    for imprint in imprints_to_add:
        session.add(Imprints(imprint_name=imprint))
    session.commit()

# %%
authors_from_df = book_df['Author'].unique()
authors_from_pg = list(author[0] for author in session.query(Authors.author_name).all())
authors_to_add = list(author for author in authors_from_df if author not in authors_from_pg)

if len(authors_to_add) > 0:
    for author in authors_to_add:
        session.add(Authors(author_name=author))
    session.commit()

# %%
books_from_pg = list(book[0] for book in session.query(Books.book_title).all())

for i in range(len(book_df)):
    title = book_df.loc[i, 'Title']
    
    if title not in books_from_pg:
        image = book_df.loc[i, 'Image']
        desc = book_df.loc[i, 'Description']
        author = book_df.loc[i, 'Author']
        imprint = book_df.loc[i, 'Imprint']

        author_id = session.query(Authors.author_id).filter(Authors.author_name == author).first()[0]
        imprint_id = session.query(Imprints.imprint_id).filter(Imprints.imprint_name == imprint).first()[0]

        session.add(Books(book_title = title, \
                             book_image = image, \
                             book_description = desc, \
                             author_id = author_id, \
                             imprint_id = imprint_id))

session.commit()

# %%
for i in range(len(book_df)):
    blist = book_df.loc[i, 'NYT List']
    title = book_df.loc[i, 'Title']
    pub_date = book_df.loc[i, 'NYT List Published Date']
    rank = int(book_df.loc[i, 'Rank'])
    weeks_on_list = int(book_df.loc[i, 'Weeks on NYT List'])
    
    list_id = session.query(Lists.list_id).filter(Lists.list_name == blist).first()[0]
    book_id = session.query(Books.book_id).filter(Books.book_title == title).first()[0]
    
    session.add(Results(list_id = list_id, \
                           book_id = book_id, \
                           published_date = pub_date, \
                           rank = rank, \
                           weeks_on_list = weeks_on_list))

session.commit()

# %%
# publisher_df = pd.read_csv('Publishers.csv')
# publisher_df
# Out:
#     publisher_id                         publisher_name
# 0              1                                  Basic
# 1              2                                  Bloom
# 2              3                          Canary Street
# 3              4                              Lioncrest
# 4              5                              Row House
# ..           ...                                    ...
# 78            79                   Science Future Press
# 79            80  South Dakota Historical Society Press
# 80            81                             Aces Press
# 81            82                   Rowman & Littlefield
# 82            83                            Zebra Press
#
# [83 rows x 2 columns]

# %%
# publishers = publisher_df['publisher_name'].unique()
# for publisher in publishers:
#     session.add(Publishers(publisher_name = publisher))
# session.commit()

# %%
# ownership_df = pd.read_csv('Ownership_v2.csv')
# ownership_df
# Out:
#                     Imprint       Publisher
# 0                     Basic           Basic
# 1                     Bloom           Bloom
# 2             Canary Street   Canary Street
# 3                 Lioncrest       Lioncrest
# 4                 Row House       Row House
# ..                      ...             ...
# 331                   Zebra     Zebra Press
# 332             Basic Books   Hachette Book
# 333            Little Brown   Hachette Book
# 334  America's Test Kitchen  Marquee Brands
# 335                 Dey St.   HarperCollins
#
# [336 rows x 2 columns]

# %%
# imprints_from_csv = ownership_df['Imprint'].unique()
# imprints_from_pg = list(imprint[0] for imprint in session.query(Imprints.imprint_name).all())
# imprints_to_add = list(imprint for imprint in imprints_from_csv if imprint not in imprints_from_pg)

# %%
# for imprint in imprints_to_add:
#     session.add(Imprints(imprint_name = imprint))
# session.commit()

# %%
# publishers_from_csv = ownership_df['Publisher'].unique()
# publishers_from_pg = list(publisher[0] for publisher in session.query(Publishers.publisher_name).all())
# publishers_to_add = list(publisher for publisher in publishers_from_csv if publisher not in publishers_from_pg)

# %%
# for i in range(len(ownership_df)):
#     imprint = ownership_df.loc[i, 'Imprint']
#     publisher = ownership_df.loc[i, 'Publisher']
    
#     imprint_id = session.query(Imprints.imprint_id).filter(Imprints.imprint_name == imprint).first()[0]
#     publisher_id = session.query(Publishers.publisher_id).filter(Publishers.publisher_name == publisher).first()[0]

#     session.add(Ownership(imprint_id = imprint_id, publisher_id = publisher_id))

# session.commit()

# %%
session.close()
